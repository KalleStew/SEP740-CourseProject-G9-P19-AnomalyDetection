# %%
# Imports

# %% [markdown]
# ## Model Architecture Setup (2.1)

# %%
# Develop fucntions here

# %%
# Test code cells here

# %% [markdown]
# ## Train Tool Implementation (2.2)

# %%
# Develop fucntions here

# %%
# Test code cells here
